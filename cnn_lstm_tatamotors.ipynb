# %%
# Imports
import numpy as np
import pandas as pd
import os
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")
import requests
import csv
from tqdm import tqdm

# %%
# For data preprocessing and analysis part
data = pd.read_csv('TTM.csv')
data
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2005-07-13  10.620000  10.640000  10.510000  10.600000   9.197446
# 1     2005-07-14  10.500000  10.500000  10.330000  10.390000   9.015231
# 2     2005-07-15  10.500000  10.650000  10.500000  10.550000   9.154059
# 3     2005-07-18  10.720000  10.740000  10.660000  10.720000   9.301566
# 4     2005-07-19  10.800000  11.030000  10.800000  10.990000   9.535840
# ...          ...        ...        ...        ...        ...        ...
# 4274  2022-07-06  26.180000  26.570000  26.129999  26.420000  26.420000
# 4275  2022-07-07  27.200001  27.879999  27.200001  27.700001  27.700001
# 4276  2022-07-08  27.750000  28.090000  27.690001  27.900000  27.900000
# 4277  2022-07-11  27.450001  27.540001  27.219999  27.260000  27.260000
# 4278  2022-07-12  26.940001  27.420000  26.860001  27.129999  27.129999
#
#       Volume
# 0     136500
# 1     136000
# 2     158700
# 3      88000
# 4     128000
# ...      ...
# 4274  623700
# 4275  715700
# 4276  355300
# 4277  341700
# 4278  506800
#
# [4279 rows x 7 columns]

# %%
data.reset_index(drop=True, inplace=True)
data.fillna(data.mean(), inplace=True)
data.head()
# Out:
# C:\Users\alauk\AppData\Local\Temp\ipykernel_43780\2985681012.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.fillna(data.mean(), inplace=True)
#          Date   Open   High    Low  Close  Adj Close  Volume
# 0  2005-07-13  10.62  10.64  10.51  10.60   9.197446  136500
# 1  2005-07-14  10.50  10.50  10.33  10.39   9.015231  136000
# 2  2005-07-15  10.50  10.65  10.50  10.55   9.154059  158700
# 3  2005-07-18  10.72  10.74  10.66  10.72   9.301566   88000
# 4  2005-07-19  10.80  11.03  10.80  10.99   9.535840  128000

# %%
data.plot(legend=True,subplots=True, figsize = (12, 6))
plt.show()
#data['Close'].plot(legend=True, figsize = (12, 6))
#plt.show()
#data['Volume'].plot(legend=True,figsize=(12,7))
#plt.show()

data.shape
data.size
data.describe(include='all').T
data.dtypes
data.nunique()
ma_day = [10,50,100]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    data[column_name]=pd.DataFrame.rolling(data['Close'],ma).mean()

data['Daily Return'] = data['Close'].pct_change()

data['Daily Return'].plot(figsize=(12,5),legend=True,linestyle=':',marker='o')
plt.show()

sns.displot(data['Daily Return'].dropna(),bins=100,color='green')
plt.show()

date=pd.DataFrame(data['Date'])
closing_df1 = pd.DataFrame(data['Close'])
close1  = closing_df1.rename(columns={"Close": "data_close"})
close2=pd.concat([date,close1],axis=1)
close2.head()

data.reset_index(drop=True, inplace=True)
data.fillna(data.mean(), inplace=True)
data.head()

data.nunique()

data.sort_index(axis=1,ascending=True)

cols_plot = ['Open', 'High', 'Low','Close','Volume','MA for 10 days','MA for 50 days','MA for 100 days','Daily Return']
axes = data[cols_plot].plot(marker='.', alpha=0.7, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily trade')

plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

data.isnull().sum()
# Out:
# C:\Users\alauk\AppData\Local\Temp\ipykernel_43780\2462714608.py:34: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.fillna(data.mean(), inplace=True)
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2005-07-13  10.620000  10.640000  10.510000  10.600000   9.197446
# 1     2005-07-14  10.500000  10.500000  10.330000  10.390000   9.015231
# 2     2005-07-15  10.500000  10.650000  10.500000  10.550000   9.154059
# 3     2005-07-18  10.720000  10.740000  10.660000  10.720000   9.301566
# 4     2005-07-19  10.800000  11.030000  10.800000  10.990000   9.535840
# ...          ...        ...        ...        ...        ...        ...
# 4274  2022-07-06  26.180000  26.570000  26.129999  26.420000  26.420000
# 4275  2022-07-07  27.200001  27.879999  27.200001  27.700001  27.700001
# 4276  2022-07-08  27.750000  28.090000  27.690001  27.900000  27.900000
# 4277  2022-07-11  27.450001  27.540001  27.219999  27.260000  27.260000
# 4278  2022-07-12  26.940001  27.420000  26.860001  27.129999  27.129999
#
#       Volume  MA for 10 days  MA for 50 days  MA for 100 days  Daily Return
# 0     136500        22.37635       22.409539        22.443703      0.000671
# 1     136000        22.37635       22.409539        22.443703     -0.019811
# 2     158700        22.37635       22.409539        22.443703      0.015399
# 3      88000        22.37635       22.409539        22.443703      0.016114
# 4     128000        22.37635       22.409539        22.443703      0.025187
# ...      ...             ...             ...              ...           ...
# 4274  623700        26.15900       26.842000        27.927200      0.010712
# 4275  715700        26.39300       26.836600        27.870600      0.048448
# 4276  355300        26.59500       26.841200        27.827600      0.007220
# 4277  341700        26.65400       26.831400        27.789100     -0.022939
# 4278  506800        26.72900       26.805000        27.728400     -0.004769
#
# [4279 rows x 11 columns]
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Adj Close          0
# Volume             0
# MA for 10 days     0
# MA for 50 days     0
# MA for 100 days    0
# Daily Return       0
# dtype: int64

# %%
cols_plot = ['Open', 'High', 'Low','Close']
axes = data[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily trade')

# %%
plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

df.describe().transpose()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2005-07-13  10.620000  10.640000  10.510000  10.600000   9.197446
# 1     2005-07-14  10.500000  10.500000  10.330000  10.390000   9.015231
# 2     2005-07-15  10.500000  10.650000  10.500000  10.550000   9.154059
# 3     2005-07-18  10.720000  10.740000  10.660000  10.720000   9.301566
# 4     2005-07-19  10.800000  11.030000  10.800000  10.990000   9.535840
# ...          ...        ...        ...        ...        ...        ...
# 4274  2022-07-06  26.180000  26.570000  26.129999  26.420000  26.420000
# 4275  2022-07-07  27.200001  27.879999  27.200001  27.700001  27.700001
# 4276  2022-07-08  27.750000  28.090000  27.690001  27.900000  27.900000
# 4277  2022-07-11  27.450001  27.540001  27.219999  27.260000  27.260000
# 4278  2022-07-12  26.940001  27.420000  26.860001  27.129999  27.129999
#
#       Volume  MA for 10 days  MA for 50 days  MA for 100 days  Daily Return
# 0     136500        22.37635       22.409539        22.443703      0.000671
# 1     136000        22.37635       22.409539        22.443703     -0.019811
# 2     158700        22.37635       22.409539        22.443703      0.015399
# 3      88000        22.37635       22.409539        22.443703      0.016114
# 4     128000        22.37635       22.409539        22.443703      0.025187
# ...      ...             ...             ...              ...           ...
# 4274  623700        26.15900       26.842000        27.927200      0.010712
# 4275  715700        26.39300       26.836600        27.870600      0.048448
# 4276  355300        26.59500       26.841200        27.827600      0.007220
# 4277  341700        26.65400       26.831400        27.789100     -0.022939
# 4278  506800        26.72900       26.805000        27.728400     -0.004769
#
# [4279 rows x 11 columns]
#                   count          mean            std       min            25%  \
# Open             4279.0  2.237445e+01      10.299331  3.170000      14.695000
# High             4279.0  2.261316e+01      10.374618  3.410000      14.900000
# Low              4279.0  2.210889e+01      10.228782  3.050000      14.505000
# Close            4279.0  2.236894e+01      10.297576  3.140000      14.725000
# Adj Close        4279.0  2.180599e+01      10.523917  2.907577      13.620653
# Volume           4279.0  1.477393e+06  939806.962446  0.000000  859950.000000
# MA for 10 days   4279.0  2.237635e+01      10.261658  3.431000      14.939500
# MA for 50 days   4279.0  2.240954e+01      10.102053  3.923000      15.077400
# MA for 100 days  4279.0  2.244370e+01       9.891112  4.185200      15.286750
# Daily Return     4279.0  6.706601e-04       0.030190 -0.179845      -0.014925
#
#                           50%           75%           max
# Open             2.099000e+01  2.935500e+01  5.126000e+01
# High             2.123000e+01  2.972000e+01  5.180000e+01
# Low              2.079000e+01  2.910000e+01  5.065000e+01
# Close            2.103000e+01  2.940500e+01  5.147000e+01
# Adj Close        2.040992e+01  2.913283e+01  5.144851e+01
# Volume           1.268200e+06  1.866100e+06  1.085910e+07
# MA for 10 days   2.109000e+01  2.939800e+01  5.049200e+01
# MA for 50 days   2.106560e+01  2.923080e+01  4.794400e+01
# MA for 100 days  2.151730e+01  2.835625e+01  4.625290e+01
# Daily Return     0.000000e+00  1.499271e-02  3.764706e-01

# %%
from sklearn.model_selection import train_test_split

X = []
Y = []
window_size=100
for i in range(1 , len(df) - window_size -1 , 1):
    first = df.iloc[i,2]
    temp = []
    temp2 = []
    for j in range(window_size):
        temp.append((df.iloc[i + j, 2] - first) / first)
    temp2.append((df.iloc[i + window_size, 2] - first) / first)
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp2).reshape(1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

train_X = train_X.reshape(train_X.shape[0],1,100,1)
test_X = test_X.reshape(test_X.shape[0],1,100,1)

# %%
print(train_X.shape, test_X.shape)
# Out:
# (3341, 1, 100, 1) (836, 1, 100, 1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError

model = tf.keras.Sequential()

# CNN layers
model.add(TimeDistributed(Conv1D(32, kernel_size=1, activation='tanh', input_shape=(None, 100, 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))

# LSTM layers
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='tanh'))
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])

history = model.fit(train_X, train_Y, validation_data=(test_X,test_Y), epochs=100,batch_size=64, verbose=1, shuffle =True)
# Out:
# Epoch 1/100
# 53/53 [==============================] - 22s 102ms/step - loss: 0.0487 - mse: 0.0487 - mae: 0.1486 - val_loss: 0.0145 - val_mse: 0.0145 - val_mae: 0.0767
# Epoch 2/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0144 - mse: 0.0144 - mae: 0.0773 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0629
# Epoch 3/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0114 - mse: 0.0114 - mae: 0.0658 - val_loss: 0.0094 - val_mse: 0.0094 - val_mae: 0.0536
# Epoch 4/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0599 - val_loss: 0.0094 - val_mse: 0.0094 - val_mae: 0.0563
# Epoch 5/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0591 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0486
# Epoch 6/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0577 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0457
# Epoch 7/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0544 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0446
# Epoch 8/100
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0532 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0441
# Epoch 9/100
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0548 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0482
# Epoch 10/100
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0526 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0441
# Epoch 11/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0517 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0453
# Epoch 12/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0515 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0441
# Epoch 13/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0515 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0420
# Epoch 14/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0503 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0426
# Epoch 15/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0495 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0431
# Epoch 16/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0499 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0413
# Epoch 17/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0498 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0405
# Epoch 18/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0512 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0511
# Epoch 19/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0520 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0496
# Epoch 20/100
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0546 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0439
# Epoch 21/100
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0516 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0405
# Epoch 22/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0492 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0400
# Epoch 23/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0482 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0467
# Epoch 24/100
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0486 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0451
# Epoch 25/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0508 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0426
# Epoch 26/100
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0486 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0402
# Epoch 27/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0492 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0399
# Epoch 28/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0481 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0391
# Epoch 29/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0480 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0412
# Epoch 30/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0479 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0464
# Epoch 31/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0474 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0400
# Epoch 32/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0472 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0411
# Epoch 33/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0473 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0394
# Epoch 34/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0471 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0416
# Epoch 35/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0471 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0473
# Epoch 36/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0471 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0417
# Epoch 37/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0475 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0386
# Epoch 38/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0466 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0426
# Epoch 39/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0485 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0378
# Epoch 40/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0471 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0404
# Epoch 41/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0476 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0389
# Epoch 42/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0466 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0427
# Epoch 43/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0464 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0436
# Epoch 44/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0470 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0401
# Epoch 45/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0480 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0388
# Epoch 46/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0446 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0434
# Epoch 47/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0479 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0384
# Epoch 48/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0460 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0385
# Epoch 49/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0459 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0429
# Epoch 50/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0468 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0412
# Epoch 51/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0474 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0428
# Epoch 52/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0469 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0384
# Epoch 53/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0453 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0396
# Epoch 54/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0460 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0423
# Epoch 55/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0485 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0372
# Epoch 56/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0439 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0390
# Epoch 57/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0456 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0429
# Epoch 58/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0462 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0398
# Epoch 59/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0448 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0375
# Epoch 60/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0455 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0389
# Epoch 61/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0456 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0405
# Epoch 62/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0454 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0407
# Epoch 63/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0438 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0399
# Epoch 64/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0444 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0416
# Epoch 65/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0454 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0389
# Epoch 66/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0460 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0419
# Epoch 67/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0449 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0378
# Epoch 68/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0443 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0375
# Epoch 69/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0445 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0394
# Epoch 70/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0446 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0385
# Epoch 71/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0452 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0422
# Epoch 72/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0457 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0392
# Epoch 73/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0441 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0368
# Epoch 74/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0447 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0394
# Epoch 75/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0441 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0378
# Epoch 76/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0442 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0418
# Epoch 77/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0440 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0382
# Epoch 78/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0444 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0375
# Epoch 79/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0454 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0389
# Epoch 80/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0438 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0455
# Epoch 81/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0448 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0414
# Epoch 82/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0451 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0379
# Epoch 83/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0429 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0441
# Epoch 84/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0436 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0384
# Epoch 85/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0444 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0376
# Epoch 86/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0434 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0374
# Epoch 87/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0441 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0371
# Epoch 88/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0436 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0385
# Epoch 89/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0445 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0439
# Epoch 90/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0442 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0411
# Epoch 91/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0431 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0387
# Epoch 92/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0437 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0405
# Epoch 93/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0438 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0397
# Epoch 94/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0435 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0451
# Epoch 95/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0441 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0367
# Epoch 96/100
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0429 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0369
# Epoch 97/100
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0453 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0425
# Epoch 98/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0435 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0424
# Epoch 99/100
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0446 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0382
# Epoch 100/100
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0433 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0380

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(history.history['mse'], label='train mse')
plt.plot(history.history['val_mse'], label='val mse')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# After the model has been constructed, we'll summarise it
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 100, 32)       64
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 50, 32)        0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 48, 128)       12416
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 24, 128)       0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 22, 64)        24640
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 11, 64)        0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 1, 704)           0
#  tributed)
#
#  bidirectional (Bidirectiona  (None, 1, 128)           393728
#  l)
#
#  dropout (Dropout)           (None, 1, 128)            0
#
#  bidirectional_1 (Bidirectio  (None, 128)              98816
#  nal)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 529,793
# Trainable params: 529,793
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.evaluate(test_X, test_Y)
# Out:
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0380
# [0.007105804979801178, 0.007105804979801178, 0.038013819605112076]

# %%
from sklearn.metrics import explained_variance_score, mean_poisson_deviance, mean_gamma_deviance
from sklearn.metrics import r2_score
from sklearn.metrics import max_error
yhat_probs = model.predict(test_X, verbose=0)
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.959787
# R2 Score: 0.959787
# Max Error: 1.107345

# %%
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
plt.figure(figsize=(20,10))
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
# Out:
# 27/27 [==============================] - 0s 9ms/step

# %% [markdown]
# # Testing part

# %% [markdown]
# In this part, the model is saved and loaded back again. Then, it's made to train again but with different data to check it's loss and prediction

# %%
model.save("model.h5")

# %%
new_model = tf.keras.models.load_model("./model.h5")

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 100, 32)       64
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 50, 32)        0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 48, 128)       12416
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 24, 128)       0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 22, 64)        24640
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 11, 64)        0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 1, 704)           0
#  tributed)
#
#  bidirectional (Bidirectiona  (None, 1, 128)           393728
#  l)
#
#  dropout (Dropout)           (None, 1, 128)            0
#
#  bidirectional_1 (Bidirectio  (None, 128)              98816
#  nal)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 529,793
# Trainable params: 529,793
# Non-trainable params: 0
# _________________________________________________________________

# %%
data2 = pd.read_csv('TTM.csv')
data2.dropna(inplace=True)
data2.head()

data2.reset_index(drop=True, inplace=True)
data2.fillna(data.mean(), inplace=True)
data2.head()
df2 = data2.drop('Date', axis=1)

print(df2)

X = []
Y = []
window_size=100
for i in range(1 , len(df2) - window_size -1 , 1):
    first = df2.iloc[i,4]
    temp = []
    temp2 = []
    for j in range(window_size):
        temp.append((df2.iloc[i + j, 4] - first) / first)
    temp2.append((df2.iloc[i + window_size, 4] - first) / first)
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp2).reshape(1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

train_X = train_X.reshape(train_X.shape[0],1,100,1)
test_X = test_X.reshape(test_X.shape[0],1,100,1)

print(len(train_X))
print(len(test_X))
# Out:
#            Open       High        Low      Close  Adj Close  Volume
# 0     10.620000  10.640000  10.510000  10.600000   9.197446  136500
# 1     10.500000  10.500000  10.330000  10.390000   9.015231  136000
# 2     10.500000  10.650000  10.500000  10.550000   9.154059  158700
# 3     10.720000  10.740000  10.660000  10.720000   9.301566   88000
# 4     10.800000  11.030000  10.800000  10.990000   9.535840  128000
# ...         ...        ...        ...        ...        ...     ...
# 4274  26.180000  26.570000  26.129999  26.420000  26.420000  623700
# 4275  27.200001  27.879999  27.200001  27.700001  27.700001  715700
# 4276  27.750000  28.090000  27.690001  27.900000  27.900000  355300
# 4277  27.450001  27.540001  27.219999  27.260000  27.260000  341700
# 4278  26.940001  27.420000  26.860001  27.129999  27.129999  506800
#
# [4279 rows x 6 columns]
# C:\Users\alauk\AppData\Local\Temp\ipykernel_43780\4138226894.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data2.fillna(data.mean(), inplace=True)
# 3341
# 836

# %%
df2
# Out:
#            Open       High        Low      Close  Adj Close  Volume
# 0     10.620000  10.640000  10.510000  10.600000   9.197446  136500
# 1     10.500000  10.500000  10.330000  10.390000   9.015231  136000
# 2     10.500000  10.650000  10.500000  10.550000   9.154059  158700
# 3     10.720000  10.740000  10.660000  10.720000   9.301566   88000
# 4     10.800000  11.030000  10.800000  10.990000   9.535840  128000
# ...         ...        ...        ...        ...        ...     ...
# 4274  26.180000  26.570000  26.129999  26.420000  26.420000  623700
# 4275  27.200001  27.879999  27.200001  27.700001  27.700001  715700
# 4276  27.750000  28.090000  27.690001  27.900000  27.900000  355300
# 4277  27.450001  27.540001  27.219999  27.260000  27.260000  341700
# 4278  26.940001  27.420000  26.860001  27.129999  27.129999  506800
#
# [4279 rows x 6 columns]

# %%
model.evaluate(test_X, test_Y)
# Out:
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0090 - mse: 0.0090 - mae: 0.0491
# [0.009043433703482151, 0.009043433703482151, 0.049121223390102386]

# %%
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data2.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
plt.figure(figsize=(20,10))
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
# Out:
# 27/27 [==============================] - 0s 9ms/step

# %%
results=get_ip
